# %% [markdown]
# <a href="https://colab.research.google.com/github/diegovalensuela/Experimetos/blob/master/Web_Scraping_Colorado_ZH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### `Extraindo os titulos de posts sobre o inter em "Colorado ZH"`

# %%
# importanto bibliotecas
import requests
from bs4 import BeautifulSoup

# %%
# guardando a url em uma variável
url = 'https://gauchazh.clicrbs.com.br/esportes/inter/ultimas-noticias/'

# %%
# fazendo uma requisição do tipo get na página e verificando o que retorna
req = requests.get(url)
print(req.content)

# %%
# fazendo uma busca no html utilizando o Soup para buscar as noticias
soup = BeautifulSoup(req.content, 'html.parser')
lista_noticias = soup.find_all('div', class_="timeline")
print(lista_noticias)
# Out:
# [<div class="timeline"><ul><div class="card card-article article photo" id="card-5ec0324ccdc9fa1d56c2e594"><time class="date-from-now" datetime="1589654089">há 8 min</time><a class="" href="/esportes/inter/noticia/2020/05/inter-prepara-proposta-de-renovacao-para-rodrigo-dourado-cka9yj31i0047015njjpqyb4h.html"><div class="article-calls"><h4 class="m-deck"><span>Ele fica?</span></h4><h2 class="m-headline">Inter prepara proposta de renovação para Rodrigo Dourado</h2><h3 class="support-text">O ex-capitão do Inter Rodrigo Dourado deve receber nas próximas semanas uma proposta de renovação de contrato. Ele tem vínculo apenas até dezembro e poderia assinar um pré-contrato com qualquer equipe...</h3><div class="info-wrapper"><strong class="author">Raphael Gomes</strong> - <time datetime="1589654089000">16/05/2020 - 15h34min</time></div></div><div class="img-container"><div class="img-wrapper"><picture class="picture-placeholder blink"><source media="(min-width: 768px)" srcset="..." title="Rodrigo Dourado/Ricardo Duarte,Internacional"/><source media="" srcset="..." title="Rodrigo Dourado/Ricardo Duarte,Internacional"/><img alt="PORTO ALEGRE (RS), 15/2/2019: o volante Rodrigo Dourado participa de treino do Inter no Beira-Rio." src="..." title="Rodrigo Dourado/Ricardo Duarte,Internacional"/></picture></div></div></a><ul class="tag-list"><li><a href="/ultimas-noticias/tag/futebol/">futebol</a></li><li><a href="/ultimas-noticias/tag/rodrigo-dourado/">rodrigo dourado</a></li><li><a href="/ultimas-noticias/tag/inter/">inter</a></li></ul></div><div class="card card-article column photo" id="card-5ebfc7bf198e892bc5832e6b"><time class="date-from-now" datetime="1589626804">há 8 horas</time><a class="" href="/colunistas/mauricio-saraiva/noticia/2020/05/desafios-de-campo-o-que-a-dupla-gre-nal-precisara-ajustar-apos-a-pandemia-cka8k38i400h0015n0oj6zqyf.html"><div class="article-calls"><h4 class="m-deck"><span>Evolução</span></h4><h2 class="m-headline">Desafios de campo: o que a dupla Gre-Nal precisará ajustar após a pandemia</h2><h3 class="support-text">Afora os prejuízos técnicos que todos os times terão por conta da longa parada, Grêmio e Inter tinham desafios anteriores à pandemia para superar caso pretendessem fazer frente, por exemplo, ao Flamen...</h3><div class="info-wrapper"><strong class="author">Maurício Saraiva</strong> - <time datetime="1589626804000">16/05/2020 - 8h0min</time></div></div><div class="img-container"><div class="img-wrapper"><picture class="picture-placeholder blink"><source media="(min-width: 768px)" srcset="..." title="Montagem sobre fotos de Mateus Bruxel/Agencia RBS e Lucas Uebel / Grêmio"/><source media="" srcset="..." title="Montagem sobre fotos de Mateus Bruxel/Agencia RBS e Lucas Uebel / Grêmio"/><img alt="Eduardo Coudet e Renato Portaluppi, técnicos de Grêmio e Inter" src="..." title="Montagem sobre fotos de Mateus Bruxel/Agencia RBS e Lucas Uebel / Grêmio"/></picture></div></div></a><ul class="tag-list"><li><a href="/ultimas-noticias/tag/inter/">inter</a></li><li><a href="/ultimas-noticias/tag/gremio/">grêmio</a></li><li><a href="/ultimas-noticias/tag/futebol/">futebol</a></li></ul></div><div class="card card-article article photo" id="card-5ebfc7bf4c5ea3b6031ad82c"><time class="date-from-now" datetime="1589626803">há 8 horas</time><a class="" href="/esportes/noticia/2020/05/como-estava-o-inter-durante-o-titulo-do-gremio-na-libertadores-de-1983-cka8c53c6006l015n49ydax78.html"><div class="article-calls"><h4 class="m-deck"><span>Saudade do Esporte</span></h4><h2 class="m-headline">Como estava o Inter durante o título do Grêmio na Libertadores de 1983</h2><h3 class="support-text">A situação de ter que ver uma grande festa da torcida do Grêmio com o título da Libertadores não era desejada pelos colorados. O problema é que o Inter tinha um compromisso em Porto Alegre naquele 28 ...</h3><div class="info-wrapper"><strong class="author">Marcos Bertoncello</strong> - <time datetime="1589626803000">16/05/2020 - 8h0min</ti ...

# %%
# percorrer a lista de noticias e printar os titulos
for lista_titulos in lista_noticias:
  lista = lista_titulos.find_all('h2', class_='m-headline')
  for lista_dados in lista:
    print(lista_dados.next_element)
# Out:
# Inter prepara proposta de renovação para Rodrigo Dourado
# Desafios de campo: o que a dupla Gre-Nal precisará ajustar após a pandemia
# Como estava o Inter durante o título do Grêmio na Libertadores de 1983
# Grupo do Inter dá boas opções a Coudet do meio para frente
# Estátua de Fernandão recebe máscara do Inter
# Anselmo, ex-Inter, renova com Al-Wehda e vira um dos jogadores mais bem pagos da Arábia Saudita
# FOTOS: com trajes de proteção ao coronavírus, funcionário do Inter recolhe bolas do lado de fora do CT Parque Gigante
# A situação do Beira-Rio e os favoritos para receber a final da Libertadores de 2021
# Confira as histórias dos profissionais que atuaram dos dois lados da rivalidade Gre-Nal
# A importância dos sócios da dupla Gre-Nal neste momento de crise
# Atitude dos jogadores do Inter merece aplausos
# "Jogo sem público é a live do futebol", diz CEO de agência de publicidade dos principais anunciantes do esporte
# Eduardo Coudet vai ter trabalho para devolver o Inter ao mesmo patamar de antes da parada
# Treinadores que venceram títulos por Grêmio e Inter
# Reforço muscular, resistência e bola: como é o modelo dos treinos de Grêmio e Inter
# Musto comenta volta aos treinos no Inter: "É importante para a cabeça pisar no campo e tocar na bola"
# Beira-Rio é candidato para receber finais de Libertadores e Sul-Americana entre 2021 e 2023
# Dupla Gre-Nal aguarda solução do mistério da próxima janela de transferências
# O alto custo de cada jogo disputado por Fernando Bob no Inter
# Luciano Hocsman tem se destacado no comando da FGF em meio a adversidades
